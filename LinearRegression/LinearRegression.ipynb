# %% [markdown]
# ## Importing Required Libraries
#
# Load the necessary libraries for data manipulation, visualization, and model evaluation:
# - `pandas` and `numpy` for handling data
# - `matplotlib.pyplot` for plotting
# - `train_test_split` from `sklearn.model_selection` for splitting data into training and testing sets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Loading the Dataset
#
# Read the dataset from a CSV file named `placement.csv`. Check for any missing values and display the full dataset for a quick overview.

# %%
df=pd.read_csv("placement.csv")
print(df.isnull().sum().sum())
df
# Out:
# 0
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## Extracting CGPA Values
#
# Select the `cgpa` column from the dataset. This column will serve as the feature (input variable) for the regression model.

# %%
cgpa_data=df.loc[:,'cgpa'].to_numpy()

print(cgpa_data.shape)

cgpa_data
# Out:
# (1000,)
# array([7.19, 7.46, 7.54, 6.42, 7.23, 7.3 , 6.69, 7.12, 6.45, 7.75, 6.82,
#        6.38, 6.58, 5.68, 7.91, 7.1 , 6.53, 7.56, 6.93, 7.63, 6.69, 7.43,
#        6.76, 6.05, 6.44, 6.28, 7.45, 6.53, 7.23, 6.51, 7.46, 7.66, 5.91,
#        6.23, 8.15, 7.48, 6.85, 8.51, 6.58, 7.25, 6.6 , 6.7 , 7.46, 7.85,
#        7.88, 6.92, 7.3 , 6.92, 6.29, 8.23, 6.2 , 6.24, 7.53, 6.69, 8.42,
#        8.12, 6.93, 7.73, 7.34, 7.7 , 7.94, 7.51, 7.61, 6.22, 6.98, 6.27,
#        6.67, 8.04, 6.58, 7.41, 6.98, 6.13, 7.9 , 6.39, 6.16, 6.77, 8.35,
#        7.1 , 8.2 , 7.63, 6.87, 7.12, 7.22, 7.38, 5.65, 6.03, 7.19, 6.96,
#        6.78, 6.56, 7.61, 7.42, 6.48, 7.  , 7.15, 6.89, 7.09, 7.33, 8.12,
#        7.46, 6.56, 6.48, 5.92, 6.44, 6.82, 6.72, 6.59, 7.32, 5.94, 7.23,
#        6.96, 6.48, 7.23, 7.24, 6.3 , 7.28, 7.16, 7.11, 6.9 , 7.  , 6.99,
#        5.91, 5.97, 6.25, 6.2 , 7.46, 7.16, 6.95, 6.76, 6.81, 5.91, 8.19,
#        7.71, 7.65, 6.33, 6.63, 7.28, 5.69, 7.53, 8.09, 6.85, 7.19, 7.66,
# ...

# %% [markdown]
# ## Extracting Placement Exam Scores and Visualizing the Data
#
# Extract the `placement_exam_marks` column to use as the target variable. Visualize the relationship between CGPA and placement scores.

# %%
placement_data=df.loc[:,'placement_exam_marks'].to_numpy()
print(placement_data.shape)
plt.scatter(cgpa_data,placement_data)
plt.xlabel("cgpa")
plt.ylabel("placement score")
plt.show()
placement_data
# Out:
# (1000,)
# array([ 26.,  38.,  40.,   8.,  17.,  23.,  11.,  39.,  38.,  94.,  16.,
#          7.,  16.,  26.,  43.,  21.,  19.,  22.,  27.,  29.,  47.,  33.,
#         54.,  11.,  11.,  58.,   8.,  46.,  19.,  15.,  16.,  44.,  11.,
#         27.,   9.,  12.,  16.,   9.,  20.,  17.,  86.,  38.,  71.,  63.,
#         55.,  10.,  15.,  46.,  42.,  28.,  18.,  28.,  27.,  33.,  36.,
#         15.,  15.,  24.,  43.,  32.,  31.,  86.,  22.,  26.,  52.,  28.,
#         31.,  18.,  30.,  44.,  17.,  20.,  19.,  12.,   3.,  56.,  12.,
#         28.,  12.,  19.,  46.,  44.,  12.,  20.,  35.,  28.,  22.,  19.,
#         39.,  17.,  15.,   6.,  63.,  30.,  21.,  35.,  28.,  52.,  76.,
#         23.,  46.,  26.,  22.,  18.,  47.,  12.,  22.,   9.,  10.,  21.,
#         31.,  33.,  15.,  10.,  77.,  37.,  21.,   0.,  54.,  39.,  46.,
#         27.,  51.,  52.,  30.,  55.,  37.,  23.,  25.,  39.,  53.,  19.,
#         18.,  64.,  93.,  47.,  15.,  53.,   8.,   5.,  22.,  18.,  41.,
# ...

# %% [markdown]
# ## Implementing Simple Linear Regression from Scratch
#
# Define a class `LR` to implement simple linear regression manually. The class contains methods for fitting the model to training data and making predictions on new data.

# %%
class LR:
    def __init__(self):
        self.gradient=None
        self.y_intercept=None

    def fit(self,X_train,Y_train):
        print(X_train.shape)
        print(Y_train.shape)
        num=0
        den=0
        for i in range(X_train.shape[0]):
            num+=(X_train[i]-X_train.mean())*(Y_train[i]-Y_train.mean())
            den+=(X_train[i]-X_train.mean())**2
        self.gradient=num/den
        self.y_intercept=Y_train.mean()-(self.gradient*X_train.mean())
        print("The gradient is: ",self.gradient)
        print("the value of y intercept is: ",self.y_intercept)

    def predict(self,X_test):
        return self.gradient*X_test+self.y_intercept

# %% [markdown]
# ## Splitting the Data
#
# Use `train_test_split` to divide the CGPA and placement score data into training and testing sets, with 20% of the data reserved for testing. Set a random seed to ensure consistent results across runs.

# %%
X_train,X_test,Y_train,Y_test=train_test_split(cgpa_data,placement_data,test_size=0.2,random_state=2)
print(X_train.shape)
print(Y_train.shape)
# Out:
# (800,)
# (800,)

# %% [markdown]
# ## Training and Visualizing the Custom Model
#
# Create an instance of the custom linear regression class. Fit the model on the training data, then visualize both training and testing predictions using scatter plots for comparison.

# %%
model=LR()

model.fit(X_train,Y_train)

y_pred=model.predict(X_train)
y_test_pred=model.predict(X_test)
plt.scatter(X_train,Y_train)
plt.scatter(X_train,y_pred)
plt.xlabel("Cgpa")
plt.ylabel("placement score")
plt.title("Training Data")
plt.show()

plt.scatter(X_test,Y_test)
plt.scatter(X_test,y_test_pred)
plt.xlabel("Cgpa")
plt.ylabel("placement score")
plt.title("Testing data")
plt.show()
# Out:
# (800,)
# (800,)
# The gradient is:  -0.26502454516087415
# the value of y intercept is:  33.97578341892782

# %% [markdown]
# ## Verifying with Scikit-Learn’s Linear Regression
#
# Train a `LinearRegression` model from scikit-learn on the same training data. Display the learned coefficients and intercept to compare with the custom implementation.

# %%
from sklearn.linear_model import LinearRegression

new_model=LinearRegression()
reshape_X,reshape_Y=X_train.reshape(-1,1),Y_train.reshape(-1,1)
new_model.fit(reshape_X,reshape_Y)
print(new_model.coef_)
print(new_model.intercept_)
# Out:
# [[-0.26502455]]
# [33.97578342]

# %% [markdown]
# ## Loading Dataset
#
# Import a dataset containing various features related to car specifications and pricing.

# %%
new_df=pd.read_csv("CarPrice_Assignment.csv")
print(new_df.isnull().sum().sum())
new_df
# Out:
# 0
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %% [markdown]
# ## Preprocessing the Data
#
# Convert categorical variables into numerical format using one-hot encoding. Drop unnecessary or non-informative columns to prepare the dataset for modeling.

# %%
df_copy=new_df.copy()
df_copy=pd.get_dummies(df_copy, columns=['fueltype'], drop_first=True)
df_copy=pd.get_dummies(df_copy, columns=['fuelsystem'], drop_first=True)
df_copy=pd.get_dummies(df_copy, columns=['drivewheel'], drop_first=True)
df_copy=pd.get_dummies(df_copy, columns=['carbody'], drop_first=True)
df_copy=pd.get_dummies(df_copy, columns=['doornumber'], drop_first=True)
df_copy=pd.get_dummies(df_copy, columns=['aspiration'], drop_first=True)
df_copy=pd.get_dummies(df_copy, columns=['enginetype'], drop_first=True)
df_copy=pd.get_dummies(df_copy, columns=['cylindernumber'], drop_first=True)
df_copy=df_copy.drop(columns=['car_ID','symboling','CarName','enginelocation'],inplace=False)
print(df_copy.dtypes)
df_copy
# Out:
# wheelbase                float64
# carlength                float64
# carwidth                 float64
# carheight                float64
# curbweight                 int64
# enginesize                 int64
# boreratio                float64
# stroke                   float64
# compressionratio         float64
# horsepower                 int64
# peakrpm                    int64
# citympg                    int64
# highwaympg                 int64
# price                    float64
# fueltype_gas                bool
# fuelsystem_2bbl             bool
# fuelsystem_4bbl             bool
# fuelsystem_idi              bool
# fuelsystem_mfi              bool
# fuelsystem_mpfi             bool
# fuelsystem_spdi             bool
# fuelsystem_spfi             bool
# drivewheel_fwd              bool
# drivewheel_rwd              bool
# carbody_hardtop             bool
# carbody_hatchback           bool
# carbody_sedan               bool
# carbody_wagon               bool
# ...

# %% [markdown]
# ## Custom Implementation of Multiple Linear Regression
#
# Define a class to perform multiple linear regression using the Normal Equation. Add a bias column to the features and compute the weights using the pseudoinverse method.

# %%
class MultipleLR:
    def __init__(self):
        self.gradient=None
        self.y_intercept=None
    def fit(self,X_train,Y_train):
        X_train = X_train.to_numpy().astype(float)
        Y_train = Y_train.to_numpy().astype(float)
        X_train=np.insert(X_train,0,1,axis=1).astype(float)
        Y_train=Y_train.astype(float)
        intercepts = np.linalg.pinv(X_train) @ Y_train

        # print(intercepts)
        self.y_intercept=intercepts[0]
        self.gradient=intercepts[1:]
        # print("...")
        # print(self.y_intercept)
        # print(self.gradient)
    def predict(self,X_test):
        return np.dot(X_test,self.gradient)+self.y_intercept

# %% [markdown]
# ## Splitting Features and Target
#
# Separate the dataset into input features and target variable. Split the data into training and testing sets to evaluate model performance.

# %%
input=df_copy.drop(columns=['price'])
output=df_copy['price']
X_train,X_test,Y_Train,Y_Test=train_test_split(input,output,test_size=0.2,random_state=42)
print(X_train.shape,Y_Train.shape)
# Out:
# (164, 41) (164,)

# %% [markdown]
# ## Training and Comparison with Scikit-Learn
#
# Train the custom model on the training data and generate predictions on the test set. Compare the learned coefficients and predictions with those obtained from scikit-learn’s `LinearRegression` for validation.

# %%
Multi_model=MultipleLR()
Multi_model.fit(X_train,Y_Train)
y_pred=Multi_model.predict(X_test)
print("Intercept: ",Multi_model.y_intercept)
print("Gradient: ",Multi_model.gradient)
print("Ypred our own",y_pred)
test_model=LinearRegression()
test_model.fit(X_train,Y_Train)
test_model_prediction=test_model.predict(X_test)
print("Intercept",test_model.intercept_)
print("Gradient: ",test_model.coef_)
print("Model's prediction: ",test_model_prediction)
# Out:
# Intercept:  -17342.79543959241
# Gradient:  [ 2.16792189e+01 -7.17732863e+01  3.64350214e+02  1.78699137e+02
#   3.61787661e+00  1.34150951e+02 -2.82624276e+03 -3.69117735e+03
#   1.69111601e+02  3.75329995e+01  2.71550161e+00 -3.09974365e+02
#   2.83043830e+02 -9.30763918e+03  9.72361334e+02  1.17321981e+03
#  -8.03515626e+03 -2.23207070e+03  7.20513455e+02 -1.73335214e+03
#   7.20646045e+02  4.57331729e+02  1.32914704e+03 -3.59973793e+03
#  -3.45388351e+03 -2.83567875e+03 -4.25321051e+03 -4.91399042e+02
#   1.48388398e+03 -1.25088138e+04  1.61912055e+03  3.93961108e+03
#   4.36034050e+03 -5.33478082e+03 -6.98601298e+02 -8.75409554e+03
#  -1.04985057e+04 -8.84380350e+03  0.00000000e+00 -1.74239418e+04
#  -6.98601298e+02]
# Ypred our own [31760.755989154677 20807.71654619823 11236.526591254158
#  12920.034772362647 28038.414198896695 5674.827486313072 9135.540151111636
#  7239.954465963543 10676.009257069018 9360.126052620653 18052.504490848332
# ...
